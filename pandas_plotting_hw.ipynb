# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# ## Homework: Plotting With Pandas
#
# _Authors: Kevin Coyle (L.A.)_
#
# ---

# %% [markdown]
# Welcome!

# %% [markdown]
# #### Pandas: Plotting Practice Problems
#
# In this homework, you're going to write code for a few problems.
#
# You'll practice the following programming concepts we've covered in class:
# * Plotting with Pandas.
# * Determining best plot given a data set.

# %% [markdown]
# #### #1. Import Pandas, `Matplotlib.pyplot`, and NumPy. Don't forget the line that makes `matplotlib` render in a Jupyter Notebook!

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %% [markdown]
# #### #2. Read in the NBA players `csv` into a variable called `nba_df`.

# %% [markdown]
# This is a data set of NBA players from 2015. The filename is `NBA_players_2015.csv`.

# %%
nba_df = pd.read_csv('./NBA_players_2015.csv')

# %% [markdown]
# #### #3. Look at the first five rows of the data set.

# %%
nba_df.head()
# Out:
#    season_end         player pos  age bref_team_id   g  gs    mp   fg   fga  \
# 0        2015     Quincy Acy   F   24          NYK  52  21  19.2  2.2   4.6
# 1        2015   Jordan Adams   G   20          MEM  18   0   7.3  1.0   2.1
# 2        2015   Steven Adams   C   21          OKC  51  50  24.2  3.0   5.5
# 3        2015    Jeff Adrien   F   28          MIN  17   0  12.6  1.1   2.6
# 4        2015  Arron Afflalo   G   29          TOT  60  54  32.5  5.0  11.8
#
#    ...   TOV%  USG%  OWS  DWS   WS  WS/48  OBPM  DBPM  BPM  VORP
# 0  ...   15.1  14.7  0.6  0.5  1.0  0.050  -2.6  -0.7 -3.4  -0.3
# 1  ...   15.9  17.7  0.0  0.2  0.2  0.076  -2.3   1.8 -0.5   0.0
# 2  ...   19.2  14.8  1.0  1.8  2.8  0.109  -2.0   2.0 -0.1   0.6
# 3  ...   12.9  14.1  0.2  0.2  0.4  0.093  -2.6   0.8 -1.8   0.0
# 4  ...   10.9  19.6  1.4  0.7  2.1  0.051  -0.2  -1.4 -1.6   0.2
#
# [5 rows x 49 columns]

# %%
nba_df.columns
# Out:
# Index(['season_end', 'player', 'pos', 'age', 'bref_team_id', 'g', 'gs', 'mp',
#        'fg', 'fga', 'fg_', 'x3p', 'x3pa', 'x3p_', 'x2p', 'x2pa', 'x2p_', 'ft',
#        'fta', 'ft_', 'orb', 'drb', 'trb', 'ast', 'stl', 'blk', 'tov', 'pf',
#        'pts', 'G', 'MP', 'PER', 'TS%', '3PAr', 'FTr', 'TRB%', 'AST%', 'STL%',
#        'BLK%', 'TOV%', 'USG%', 'OWS', 'DWS', 'WS', 'WS/48', 'OBPM', 'DBPM',
#        'BPM', 'VORP'],
#       dtype='object')

# %% [markdown]
# #### #4. Create a histogram of the `age` column.

# %%
nba_df['age'].plot(kind = 'hist')

# %% [markdown]
# #### #5. Create a histogram of the `age` column, but change the number of bins to `20`.

# %%
nba_df['age'].plot(kind = 'hist', bins = 20)

# %% [markdown]
# #### #6. Discuss the difference in the two plots and the implications.

# %% [markdown]
# While skewed, the plot with fewer bins leads one to believe that the bin to the right of the highest-numbered age bin is the second largest. The second-largest bin occurs right after 22 and before 25. Having more number of bins allow for a better understanding of each unique datapoint.

# %% [markdown]
# #### #7. Rename the `position` column `'pos'` with the following `C:5`, `G:1`, and `F:3`. Then create a scatter matrix plot with the `'pos'`, `'pts'`, `'age'`, and `'fg'` columns.

# %%
nba_df['pos'].rename(index={'C':'5', 'G':'1', 'F':'3'}, inplace=True)
nba_df.head()
# Out:
#    season_end         player  pos  age bref_team_id   g  gs    mp   fg   fga  \
# 0        2015     Quincy Acy    3   24          NYK  52  21  19.2  2.2   4.6
# 1        2015   Jordan Adams    1   20          MEM  18   0   7.3  1.0   2.1
# 2        2015   Steven Adams    5   21          OKC  51  50  24.2  3.0   5.5
# 3        2015    Jeff Adrien    3   28          MIN  17   0  12.6  1.1   2.6
# 4        2015  Arron Afflalo    1   29          TOT  60  54  32.5  5.0  11.8
#
#    ...   TOV%  USG%  OWS  DWS   WS  WS/48  OBPM  DBPM  BPM  VORP
# 0  ...   15.1  14.7  0.6  0.5  1.0  0.050  -2.6  -0.7 -3.4  -0.3
# 1  ...   15.9  17.7  0.0  0.2  0.2  0.076  -2.3   1.8 -0.5   0.0
# 2  ...   19.2  14.8  1.0  1.8  2.8  0.109  -2.0   2.0 -0.1   0.6
# 3  ...   12.9  14.1  0.2  0.2  0.4  0.093  -2.6   0.8 -1.8   0.0
# 4  ...   10.9  19.6  1.4  0.7  2.1  0.051  -0.2  -1.4 -1.6   0.2
#
# [5 rows x 49 columns]

# %%
pd.plotting.scatter_matrix(nba_df[['pos', 'pts', 'age', 'fg']], figsize=(12,12))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000000B020AC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000B7F6E10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000B820390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000B847908>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000000000B870E80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000B8A0438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000B8C69B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000B8EFF60>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000000000B8EFF98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000B944A58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000B971FD0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000B99E588>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000000000B9C7B00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000B9F60B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000BA1D630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000BA44BA8>]],
#       dtype=object)

# %% [markdown]
# #### #8. Plot the number of guards, centers, and forwards in this data set.

# %%
nba_df['pos'].value_counts().plot(kind='bar')

# %% [markdown]
# The end!

# %% [markdown]
# #### Great job!
